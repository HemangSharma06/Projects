# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder as OE
from sklearn.model_selection import train_test_split as TTS
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score as AS,recall_score as rs,f1_score as f1,precision_score as ps , confusion_matrix as cfm
from imblearn.over_sampling import SMOTE

# %%
data = pd.read_csv('predictive_maintenance.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %%
data.isnull().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
data = data.drop(columns=['UDI', 'Product ID', 'Failure Type'])

# %%
data.head()
# Out:
#   Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0    M                298.1                    308.6                    1551
# 1    L                298.2                    308.7                    1408
# 2    L                298.1                    308.5                    1498
# 3    L                298.2                    308.6                    1433
# 4    L                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target
# 0         42.8                0       0
# 1         46.3                3       0
# 2         49.4                5       0
# 3         39.5                7       0
# 4         40.0                9       0

# %%
col = data['Type'].unique()
oe = OE(categories=[col])
data['Type'] = oe.fit_transform(data[['Type']])
data.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0   0.0                298.1                    308.6                    1551
# 1   1.0                298.2                    308.7                    1408
# 2   1.0                298.1                    308.5                    1498
# 3   1.0                298.2                    308.6                    1433
# 4   1.0                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target
# 0         42.8                0       0
# 1         46.3                3       0
# 2         49.4                5       0
# 3         39.5                7       0
# 4         40.0                9       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Type                     10000 non-null  float64
#  1   Air temperature [K]      10000 non-null  float64
#  2   Process temperature [K]  10000 non-null  float64
#  3   Rotational speed [rpm]   10000 non-null  int64
#  4   Torque [Nm]              10000 non-null  float64
#  5   Tool wear [min]          10000 non-null  int64
#  6   Target                   10000 non-null  int64
# dtypes: float64(4), int64(3)
# memory usage: 547.0 KB

# %%
x = data.iloc[:,:-1]
y = data['Target']

# %%
s = SMOTE(random_state=42)
x_res, y_res = s.fit_resample(x,y)

# %%
x_res.shape, y_res.shape
# Out:
# ((19322, 6), (19322,))

# %%
x_train, x_test, y_train, y_test = TTS(x_res, y_res, test_size=0.2, random_state=42)

# %%
sv = SVC(random_state=42, class_weight='balanced', probability=True)
sv.fit(x_train, y_train)
# Out:
# SVC(class_weight='balanced', probability=True, random_state=42)

# %%
y_pred = sv.predict(x_test)

# %%
print(f"Without Noise Tolerance\nAccuracy = {AS(y_test, y_pred)*100}\nRecall = {rs(y_test, y_pred)*100}\nf1 = {f1(y_test, y_pred)*100}\nPrecision = {ps(y_test, y_pred)*100}")
# Out:
# Without Noise Tolerance
# Accuracy = 83.88098318240621
# Recall = 86.5872604867944
# f1 = 84.29543735820519
# Precision = 82.12180746561886

# %%
from sklearn.metrics import ConfusionMatrixDisplay as CMD
import matplotlib.pyplot as plt

mat = cfm(y_test, y_pred)

disp = CMD(confusion_matrix=mat, display_labels=sv.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np
x_test_noisy = x_test.copy()
noise = np.random.normal(0, 0.05, x_test.shape)
x_test_noisy += noise

y_pred_noisy = sv.predict(x_test_noisy)

f1_noisy = f1(y_test, y_pred_noisy)
print(f"F1 Score on Noisy Data: {f1_noisy*100}")
f1_noisy = AS(y_test, y_pred_noisy)
print(f"Accuracy Score on Noisy Data: {f1_noisy*100}")
f1_noisy = rs(y_test, y_pred_noisy)
print(f"Recall Score on Noisy Data: {f1_noisy*100}")
f1_noisy = ps(y_test, y_pred_noisy)
print(f"Precision Score on Noisy Data: {f1_noisy*100}")
# Out:
# F1 Score on Noisy Data: 84.28751576292561
# Accuracy Score on Noisy Data: 83.88098318240621
# Recall Score on Noisy Data: 86.53547384774728
# Precision Score on Noisy Data: 82.15339233038348

# %%
import time

start_train = time.time()
sv.fit(x_train, y_train)
end_train = time.time()
train_time = end_train - start_train
print(f"Training time: {train_time:.4f} seconds")

start_pred = time.time()
y_pred = sv.predict(x_test)
end_pred = time.time()
pred_time = end_pred - start_pred
print(f"Prediction time: {pred_time:.4f} seconds")

# %%
from sklearn.metrics import roc_curve, auc, RocCurveDisplay as RCD
y_probs = sv.predict_proba(x_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_probs)

roc_auc = auc(fpr, tpr)
print(f"AUC Score: {roc_auc:.4f}")

import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Recall)')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# AUC Score: 0.9091
